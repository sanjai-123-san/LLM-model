# %%
# !unzip create-llm-main.zip -d create-llm-main
# Out:
# Archive:  create-llm-main.zip
# 88aea8ae1a7aecce973975862f087df87e74c525
#    creating: create-llm-main/create-llm-main/
#   inflating: create-llm-main/create-llm-main/.dockerignore
#    creating: create-llm-main/create-llm-main/.github/
#    creating: create-llm-main/create-llm-main/.github/workflows/
#   inflating: create-llm-main/create-llm-main/.github/workflows/docker.yml
#   inflating: create-llm-main/create-llm-main/.gitignore
#   inflating: create-llm-main/create-llm-main/ARCHITECTURE.md
#   inflating: create-llm-main/create-llm-main/CHANGELOG.md
#   inflating: create-llm-main/create-llm-main/CONTRIBUTING.md
#   inflating: create-llm-main/create-llm-main/DEVELOPMENT.md
#   inflating: create-llm-main/create-llm-main/DOCKER.md
#   inflating: create-llm-main/create-llm-main/Dockerfile
#   inflating: create-llm-main/create-llm-main/Dockerfile.cli
#   inflating: create-llm-main/create-llm-main/Dockerfile.training
#   inflating: create-llm-main/create-llm-main/LICENSE
# ...
